# %% [markdown]
# # 1. Gen inventory.csv

# %%
import pandas as pd
import random

# Đọc dữ liệu gốc
df = pd.read_csv("fragrance_collection.csv")

# Lấy ngẫu nhiên 300 dòng
inventory = df[['Brand', 'Name']].sample(n=300, random_state=42).reset_index(drop=True)

# Thêm cột Quantity với giá trị ngẫu nhiên từ 1 đến 20
inventory['Quantity'] = [random.randint(1, 20) for _ in range(300)]

# %%
inventory.head(10)
# Out:
#                               Brand  \
# 0                             Jovan
# 1                           Amouage
# 2                           Dunhill
# 3                           Batalat
# 4                    Giorgio Armani
# 5                          Kun Safi
# 6                           Bvlgari
# 7               Salvatore Ferragamo
# 8                               B96
# 9  Joyau Unique & Sensoriel Parfums
#
#                                             Name  Quantity
# 0                               Jovan Black Musk         9
# 1                               Amouage Sunshine        17
# 2                      Dunhill Desire Blue Ocean         9
# 3               Batalat Clementine Lmprober Oud         12
# 4                Giorgio Armani My Way Gift Set          8
# 5               Kun Safi Honey Safi Perfume Oil          7
# 6            Bvlgari Omnia Crystalline Gift Set          9
# 7         Salvatore Ferragamo Signorina In Fiore         3
# 8          B96 Michel Girard Geranium Pepper EDP         2
# 9  Joyau Unique & Sensoriel Parfums Coffeeze EDP        18

# %% [markdown]
# # 2. Convert SAR to VND

# %%
df = pd.read_csv("fragrance_collection.csv")

# Price SAR -> VND
df['Price'] = df['Price'] * 6900

# %%
df.to_csv("fragrance_collection_vnd.csv", index=False)

# %% [markdown]
# # 3. FAISS VectorDB

# %%
import pandas as pd
from langchain.schema import Document
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# %%
df = pd.read_csv("fragrance_collection_vnd.csv")

def row_to_document(row):
    text = " | ".join([f"{col}: {str(row[col])}" for col in row.index if col not in ['Price', 'image', 'Rate', 'Rating_count', 'Size', 'Year']])
    return Document(page_content=text)

documents = [row_to_document(row) for _, row in df.iterrows()]

documents[:5]
# Out:
# [Document(page_content="Name: Dolce & Gabanna L'imperatrice 3 Pour Femme | Description: Perfume for the energetic woman who is a hero in her movie in life every day! It keeps you vibrant and sparkling with irresistible attractiveness, a combination of kiwi, lemon and sandalwood. | Brand: Dolce&Gabbana | Gender: Women | Product_Type: Perfume | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: watermerlon, kiwi, pink cyclamen, musk, pink pepper, jasmine, sandalwood, lemon tree | Concentration: Eau de Toilette | Top_note: pink pepper, kiwi, rhubarb | Middle_note: jasmine, cyclamen, watermelon | Base_note: musk, sandalwood, lemon trees."),
#  Document(page_content='Name: Roberto Cavalli Paradiso | Description: Woody floral fragrance, a subtle aroma that makes you feel fresh with a stunning blend of citrus, jasmine, and cypress. | Brand: Roberto Cavalli | Gender: Women | Product_Type: Perfume | Character_x: Romantic | Fragrance_Family: Woody | Ingredients: citrus, mandarin, bergamot, jasmine, pine, cypress, laurel. | Concentration: Eau de Parfum | Top_note: citruses , mandarin , bergamot | Middle_note: jasmine | Base_note: cypress, parasol pine, pink laurel'),
#  Document(page_content='Name: Yves Saint Laurent Libre | Description: This perfume is a reflection of Freedom, specially designed for bold women, for those who live by their own rules, to enjoy the unique fusion of French lavender & orange blossoms from Morrocco. A statement of freedom with an additional whiff of daring musky notes. | Brand: Yves Saint Laurent | Gender: Women | Product_Type: Perfume | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: mandarin orange, lavendar, black currant, petitgrain, jasmine, orange blossom, vanilla, cedar, musk, ambergris | Concentration: Eau de Parfum | Top_note: mandarin orange, lavendar, black currant, petitgrain | Middle_note: jasmine, orange blossom | Base_note: vanilla, cedar, musk, ambergris'),
#  Document(page_content='Name: Mancera Red Tobacco | Description: Mancera Red Tobacco is the new oriental, woody fragrance for men and women. Its the best oriental scent, full of life and attractiveness. This perfume contains a very high quality ingredients. A must have perfume!: | Brand: Mancera | Gender: Women | Product_Type: Perfume | Character_x: Romantic | Fragrance_Family: Oriental | Ingredients: saffron, cinnamon, incense, nutmeg, white peach, green apple & nepalese oud, leaves of patchouli, delicate jasmine, precious tobacco, amber, woody notes, vetiver, vanilla pods, white musk. | Concentration: Eau de Parfum | Top_note: saffron, cinnamon, incense, nutmeg, white peach, green apple, nepalese | Middle_note: patchouli, jasmine | Base_note: tobacco, amber, woody notes, vetiver, vanilla, white musk'),
#  Document(page_content='Name: Giorgio Armani Emporio Armani Stronger With You Intensely | Description: for every romantic gentle man, This strong fascinating fragrance is for you. It was released to capture all people hearts from the first smell to tell a story of an outstanding emotional man who is deeply in love and is ready to do anything for their lovers. | Brand: Giorgio Armani | Gender: Men | Product_Type: Perfume | Character_x: Romantic | Fragrance_Family: Aromatic | Ingredients: spices, violet, lavender, sweet toffee, caramel, cinnamon, suede, vanilla, amber | Concentration: Eau de Parfum | Top_note: pink pepper, juniper, violet leaf | Middle_note: lavender, sage, toffee, cinnamon | Base_note: tonka bean, suede, amber, vanilla')]

# %%
# HuggingFace Embedding
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# FAISS index
db = FAISS.from_documents(documents, embedding_model)

# Save FAISS index
db.save_local("faiss_index")

# %%
# Usage
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# Load FAISS index from folder
db = FAISS.load_local("faiss_index", 
                      embedding_model,
                      allow_dangerous_deserialization=True)

# %%
# !pip install -q deep-translator
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phatvu/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.12.14)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
from deep_translator import GoogleTranslator

translator = GoogleTranslator()

# Similarity search
query = "chai nước hoa nữ"
query = GoogleTranslator(source='vi', target='en').translate(query)
print(query)

results = db.similarity_search(query, k=100)

# Print results
for doc in results:
    print(doc.page_content)
# Out:
# Women's perfume bottle
# Name: Burberry Her Perfume Set  | Description: An exquisite perfume set for women that contains a 100 ml EDP, in addition to a 7.5 ml bottle of the same perfume and a 75 ml perfumed body lotion.
# The set comes to you in a distinctive and elegant package, which you could easily gift to your beloved ones on happy and special occasions.
# The scent of the perfume embodies the young and lively spirit of the charming city of London, the creative city with its ancient pillars.
# The floral heart of the scent highlights the subtle details of your delicate femininity and highlights your beauty. | Brand: Burberry | Gender: Women | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: lemon, mandarin, black currant, sour cherry, blackberry, raspberry, strawberry, jasmine, violet, patchouli, amber, woods, cashmeran, oak moss, vanilla, musk | Concentration: Eau de Parfum | Top_note: lemon, mandarin, black currant, sour cherry, blackberry, raspberry, strawberry | Middle_note: jasmine, violet | Base_note: patchouli, amber, woods, cashmeran, oak moss, vanilla, musk
# Name: Versace Miniatures Collection Perfume Set  | Description: Aromatic perfume set for men and women carrying 5 types of luxurious and surprising perfumes.
# Each fragrance in the collection is carefully designed to fulfill your dream of elegance and distinction.
# Perfumes have varied scents to suit all occasions of your life and days.
# The set comes to you in a special gift box that you can present as a gift to everyone you love. | Brand: Versace | Gender: Women | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown
# Name:
# This perfect perfume deserves to be included in your perfume collection. | Brand: Versace | Gender: Women | Product_Type: Hair Mist | Character_x: Dynamic | Fragrance_Family: Citrus | Ingredients: tangerine, lemon, pink pepper, blossoms of black currant, jasmine, freesia, guava, cedar wood, musk | Concentration: Eau de Parfum | Top_note: tangerine, lemon, pink pepper | Middle_note: blossoms of black currant, jasmine, freesia, guava | Base_note: cedar wood, musk
# Name: Elie Saab Girl Of Now Gift Set  | Description: It's a fragrance set for women featuring (50 ml) bottle of the fragrance, body lotion and an elegant makeup pouch.
# The collection comes to you in an elegant box so you can offer it to your beloved ones on special occasions.
# The delicious composition has notes of pistachio and almond milk, which is all that a woman needs to reveal her beauty.
# Enjoy all your busy days and special nights with the delicate creamy fragrance that keeps you refreshed. | Brand: Elie Saab | Gender: Women | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown
# Name: Burberry Gift Set For Men  | Description: The two-piece set contains two of MR Burberry Eau de Toilette (100 ml, 30 ml). This fragrance is the masculine version of the Eau de Parfum, which comes in a classic structure to suit you on all of your occasions, thanks to its aromatic notes of tarragon, vetiver and cedar. | Brand: Burberry | Gender: Men | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Floral | Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown
# Name: Givenchy Irresistible Set  | Description: It's a perfume set for women, featuring (50 ml) of the fragrance bottle and another (15ml) bottle.
# It comes to you in an elegant packaging so you can offer it as a gift to your beloved ones.
# It's designed in a small size so you can take on your travels.
# The fragrance is irresistable, featuring rare and precious components to deliver a wonderful scent. | Brand: Givenchy | Gender: Women | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Oriental | Ingredients: mallow musk, pear, iris, rose, cedar, musk, iris  | Concentration: Eau de Parfum | Top_note: mallow musk, pear | Middle_note: iris, rose | Base_note: cedar, musk
# Name: Cartier Variety Travel Mini Set  | Description: A fragrance set for men and women that contains four mini Cartier perfumes (Eau de Perfume) with their distinctive scents. Declaration EDT 4 ml + Declaration Parfum 4 ml + L'envol EDP 5 ml + Eau De Cartier EDT 5 ml
# The fragrances are all in small sizes, that can easily accompany you on the go.
# The set comes to you in an elegant and distinctive package that you can present as a gift to everyone you love on happy and special occasions.
# Enjoy the variety of fragrances that will present you with different choices for different occasions. | Brand: Cartier | Gender: Women | Product_Type: Perfume Set | Character_x: Romantic | Fragrance_Family: Aromatic | Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown
# Name: Moschino Toy 2 Gift Set  | Description: An aromatic set for women that contains a 100 ml Eau de Parfum, in addition to mini travel spray in 10 ml and a 200ml soothing and fragrant skin lotion
# The set comes in an elegant and distinctive package that you can present as a gift to everyone you love on happy occasions
# The collection represents everything a woman needs to achieve high levels of beauty
# The lotion drops off your skin and the perfume spreads around you to express your femininity and increase the charm of your look | Brand: Moschino | Gender: Women | Product_Type: Perfume | Character_x: Natural | Fragrance_Family: Aromatic | Ingredients: mongolia, mandarin, orange, jasmine, peony, white currant, sandalwood, amber wood, musk | Concentration: Eau de Parfum | Top_note: mongolia, mandarin, orange | Middle_note: jasmine, peony, white currant | Base_note: sandalwood, amber wood, musk
# Name: Prada Small Set  | Description: A small set of four fragrances (Les Infusion De Prada Iris 8 ml EDP, La Femme 9 ml EDP, La Femme 9 ml EDP, Candy Florale 7 ml EDT )
# This collection is specially designed for elegant women who prefer to stand out.
# Enjoy different, attractive looks with this amazing set.
# The set is easy to carry with you anywhere.
Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown
# Name: Oud Lover Box Almonasabat | Description: This distinctive box is designed for special occasions. It features a collection of Ashek Al Oud products. The elegant box is designed so you can offer it as a gift to your beloved ones. | Brand: Oud Lover | Gender: Unisex | Product_Type: Oud | Character_x: Charismatic | Fragrance_Family: Oud | Ingredients: unknown | Concentration: Eau de Parfum | Top_note: unknown | Middle_note: unknown | Base_note: unknown

# %% [markdown]
# # 4. Build SQLite

# %%
import pandas as pd
import sqlite3

# Load CSV files
fragrance_df = pd.read_csv("fragrance_collection_vnd.csv")
inventory_df = pd.read_csv("inventory.csv")

# Tạo connection tới SQLite DB (sẽ tạo file nếu chưa có)
conn = sqlite3.connect("perfumes.db")

# Đưa dữ liệu vào các bảng SQLite
fragrance_df.to_sql("fragrance_collection", conn, if_exists="replace", index=False)
inventory_df.to_sql("inventory", conn, if_exists="replace", index=False)

# Đóng connection
conn.close()

# %%
import sqlite3

conn = sqlite3.connect("perfumes.db")
cursor = conn.cursor()

# Kiểm tra 5 dòng đầu trong bảng
cursor.execute("SELECT * FROM fragrance_collection LIMIT 5")
print(cursor.fetchall())

cursor.execute("SELECT * FROM inventory LIMIT 5")
print(cursor.fetchall())

conn.close()
# Out:
# [("Dolce & Gabanna L'imperatrice 3 Pour Femme", 1373100, 'Perfume for the energetic woman who is a hero in her movie in life every day! It keeps you vibrant and sparkling with irresistible attractiveness, a combination of kiwi, lemon and sandalwood.', '5', '6', 'https://assets.goldenscent.com/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/3/4/3423473020615-dolce-_-gabbana-l_imperatrice-01_1_.png', 'Dolce&Gabbana', 'Women', 'Perfume', 'Romantic', 'Floral', '100 ml', 2009, 'watermerlon, kiwi, pink cyclamen, musk, pink pepper, jasmine, sandalwood, lemon tree', 'Eau de Toilette', 'pink pepper, kiwi, rhubarb', 'jasmine, cyclamen, watermelon', 'musk, sandalwood, lemon trees.'), ('Roberto Cavalli Paradiso', 1166100, 'Woody floral fragrance, a subtle aroma that makes you feel fresh with a stunning blend of citrus, jasmine, and cypress.', '4.95', '17', 'https://assets.goldenscent.com/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/3/6/3607347733423c-roberto-cavalli-paradiso---75-ml.jpg', 'Roberto Cavalli', 'Women', 'Perfume', 'Romantic', 'Woody', '50 ml', 2015, 'citrus, mandarin, bergamot, jasmine, pine, cypress, laurel.', 'Eau de Parfum', 'citruses , mandarin , bergamot', 'jasmine', 'cypress, parasol pine, pink laurel'), ('Yves Saint Laurent Libre', 2684100, 'This perfume is a reflection of Freedom, specially designed for bold women, for those who live by their own rules, to enjoy the unique fusion of French lavender & orange blossoms from Morrocco. A statement of freedom with an additional whiff of daring musky notes.', '5', '3', 'https://assets.goldenscent.com/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/3/6/3614272648418c-yves-saint-laurent-libre---90-ml_1_.jpg', 'Yves Saint Laurent', 'Women', 'Perfume', 'Romantic', 'Floral', '90 ml', 2019, 'mandarin orange, lavendar, black currant, petitgrain, jasmine, orange blossom, vanilla, cedar, musk, ambergris', 'Eau de Parfum', 'mandarin orange, lavendar, black currant, petitgrain', 'jasmine, orange blossom', 'vanilla, cedar, musk, ambergris'), ('Mancera Red Tobacco', 3443100, 'Mancera Red Tobacco is the new oriental, woody fragrance for men and women. Its the best oriental scent, full of life and attractiveness. This perfume contains a very high quality ingredients. A must have perfume!:', '4.38', '8', 'https://assets.goldenscent.com/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/3/6/3607347733423c-mancera-red-tobacco---120-ml.jpg', 'Mancera', 'Women', 'Perfume', 'Romantic', 'Oriental', '120 ml', 2017, 'saffron, cinnamon, incense, nutmeg, white peach, green apple & nepalese oud, leaves of patchouli, delicate jasmine, precious tobacco, amber, woody notes, vetiver, vanilla pods, white musk.', 'Eau de Parfum', 'saffron, cinnamon, incense, nutmeg, white peach, green apple, nepalese', 'patchouli, jasmine', 'tobacco, amber, woody notes, vetiver, vanilla, white musk'), ('Giorgio Armani Emporio Armani Stronger With You Intensely', 2753100, 'for every romantic gentle man, This strong fascinating fragrance is for you. It was released to capture all people hearts from the first smell to tell a story of an outstanding emotional man who is deeply in love and is ready to do anything for their lovers.', '5', '3', 'https://assets.goldenscent.com/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/3/6/3614272225718-giorgio-armani-emporio-armani-stronger-with-you-intensely.jpg', 'Giorgio Armani', 'Men', 'Perfume', 'Romantic', 'Aromatic', '100 ml', 2019, 'spices, violet, lavender, sweet toffee, caramel, cinnamon, suede, vanilla, amber', 'Eau de Parfum', 'pink pepper, juniper, violet leaf', 'lavender, sage, toffee, cinnamon', 'tonka bean, suede, amber, vanilla')]
# [('Jovan', 'Jovan Black Musk', 11), ('Amouage', 'Amouage Sunshine', 16), ('Dunhill', 'Dunhill Desire Blue Ocean', 9), ('Batalat', 'Batalat Clementine Lmprober Oud ', 12), ('Giorgio Armani', 'Giorgio Armani My Way Gift Set ', 8)]

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# Load model local
model_id = "phatvucoder/Qwen2.5-1.5B-Perfumassist"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=512)
llm = HuggingFacePipeline(pipeline=pipe)

# Tạo database và agent như trên
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent

db = SQLDatabase.from_uri("sqlite:///perfumes.db")
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

agent = create_sql_agent(llm=llm, toolkit=toolkit, verbose=True)
agent.run("Loại nước hoa nào có tone hương vani?")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use mps:0
# /var/folders/h3/4_pq_7pd3pq2286xkp78c1480000gn/T/ipykernel_26157/196035688.py:10: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   llm = HuggingFacePipeline(pipeline=pipe)
# /var/folders/h3/4_pq_7pd3pq2286xkp78c1480000gn/T/ipykernel_26157/196035688.py:21: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   agent.run("Loại nước hoa nào có tone hương vani?")
# > Entering new SQL Agent Executor chain...
# /Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py:2208: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on mps. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('mps') before running `.generate()`.
#   warnings.warn(
# Exception in thread Thread-11 (generate):
# Traceback (most recent call last):
#   File "/Users/phatvu/miniconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/phatvu/.local/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/phatvu/miniconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py", line 2326, in generate
#     result = self._sample(
#              ^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py", line 3286, in _sample
#     outputs = self(**model_inputs, return_dict=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/utils/deprecation.py", line 172, in wrapped_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/models/qwen2/modeling_qwen2.py", line 855, in forward
#     outputs = self.model(
#               ^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/transformers/models/qwen2/modeling_qwen2.py", line 535, in forward
#     inputs_embeds = self.embed_tokens(input_ids)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/modules/sparse.py", line 163, in forward
#     return F.embedding(
#            ^^^^^^^^^^^^
#   File "/Users/phatvu/miniconda3/lib/python3.11/site-packages/torch/nn/functional.py", line 2264, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Placeholder storage has not been allocated on MPS device!
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# Cell In[37], line 21
#      18 toolkit = SQLDatabaseToolkit(db=db, llm=llm)
#      20 agent = create_sql_agent(llm=llm, toolkit=toolkit, verbose=True)
# ---> 21 agent.run("Loại nước hoa nào có tone hương vani?")
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:598, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     596     if len(args) != 1:
#     597         raise ValueError("`run` supports only one positional argument.")
# --> 598     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     599         _output_key
#     600     ]
#     602 if kwargs and not args:
#     603     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     604         _output_key
#     605     ]
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:381, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     349 """Execute the chain.
#     350
#     351 Args:
#    (...)
#     372         `Chain.output_keys`.
#     373 """
#     374 config = {
#     375     "callbacks": callbacks,
#     376     "tags": tags,
#     377     "metadata": metadata,
#     378     "run_name": run_name,
#     379 }
# --> 381 return self.invoke(
#     382     inputs,
#     383     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     384     return_only_outputs=return_only_outputs,
#     385     include_run_info=include_run_info,
#     386 )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1331, in <listcomp>(.0)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1359, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1356     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1358     # Call the LLM to see what to do.
# -> 1359     output = self._action_agent.plan(
#    1360         intermediate_steps,
#    1361         callbacks=run_manager.get_child() if run_manager else None,
#    1362         **inputs,
#    1363     )
#    1364 except OutputParserException as e:
#    1365     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:462, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     454 final_output: Any = None
#     455 if self.stream_runnable:
#     456     # Use streaming to make sure that the underlying LLM is invoked in a
#     457     # streaming
#    (...)
#     460     # Because the response from the plan is not a generator, we need to
#     461     # accumulate the output into final output and return that.
# --> 462     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     463         if final_output is None:
#     464             final_output = chunk
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3262, in RunnableSequence.stream(self, input, config, **kwargs)
#    3256 def stream(
#    3257     self,
#    3258     input: Input,
#    3259     config: Optional[RunnableConfig] = None,
#    3260     **kwargs: Optional[Any],
#    3261 ) -> Iterator[Output]:
# -> 3262     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3249, in RunnableSequence.transform(self, input, config, **kwargs)
#    3243 def transform(
#    3244     self,
#    3245     input: Iterator[Input],
#    3246     config: Optional[RunnableConfig] = None,
#    3247     **kwargs: Optional[Any],
#    3248 ) -> Iterator[Output]:
# -> 3249     yield from self._transform_stream_with_config(
#    3250         input,
#    3251         self._transform,
#    3252         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3253         **kwargs,
#    3254     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:2056, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2054 try:
#    2055     while True:
# -> 2056         chunk: Output = context.run(next, iterator)  # type: ignore
#    2057         yield chunk
#    2058         if final_output_supported:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3212, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3209     else:
#    3210         final_pipeline = step.transform(final_pipeline, config)
# -> 3212 yield from final_pipeline
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:5300, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5294 def transform(
#    5295     self,
#    5296     input: Iterator[Input],
#    5297     config: Optional[RunnableConfig] = None,
#    5298     **kwargs: Any,
#    5299 ) -> Iterator[Output]:
# -> 5300     yield from self.bound.transform(
#    5301         input,
#    5302         self._merge_configs(config),
#    5303         **{**self.kwargs, **kwargs},
#    5304     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:571, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     564 except BaseException as e:
#     565     run_manager.on_llm_error(
#     566         e,
#     567         response=LLMResult(
#     568             generations=[[generation]] if generation else []
#     569         ),
#     570     )
# --> 571     raise e
#     572 else:
#     573     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:555, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     553 generation: Optional[GenerationChunk] = None
#     554 try:
# --> 555     for chunk in self._stream(
#     556         prompt, stop=stop, run_manager=run_manager, **kwargs
#     557     ):
#     558         yield chunk.text
#     559         if generation is None:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_community/llms/huggingface_pipeline.py:357, in HuggingFacePipeline._stream(self, prompt, stop, run_manager, **kwargs)
#     354 t1 = Thread(target=self.pipeline.model.generate, kwargs=generation_kwargs)
#     355 t1.start()
# --> 357 for char in streamer:
#     358     chunk = GenerationChunk(text=char)
#     359     if run_manager:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/generation/streamers.py:226, in TextIteratorStreamer.__next__(self)
#     225 def __next__(self):
# --> 226     value = self.text_queue.get(timeout=self.timeout)
#     227     if value == self.stop_signal:
#     228         raise StopIteration()
#
# File ~/miniconda3/lib/python3.11/queue.py:179, in Queue.get(self, block, timeout)
#     177         remaining = endtime - time()
#     178         if remaining <= 0.0:
# --> 179             raise Empty
#     180         self.not_empty.wait(remaining)
#     181 item = self._get()
#
# Empty:

# %%
# !pip install -q langchain_huggingface
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chat-with-mlx 0.2.2 requires chromadb==0.5.0, which is not installed.
# langchain-chroma 0.1.2 requires chromadb<0.6.0,>=0.4.0, which is not installed.
# chat-with-mlx 0.2.2 requires langchain==0.1.16, but you have langchain 0.2.15 which is incompatible.
# chat-with-mlx 0.2.2 requires langchain-core==0.1.45, but you have langchain-core 0.3.49 which is incompatible.
# chat-with-mlx 0.2.2 requires pypdf==4.2.0, but you have pypdf 4.3.1 which is incompatible.
# langchain-chroma 0.1.2 requires langchain-core<0.3,>=0.1.40, but you have langchain-core 0.3.49 which is incompatible.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.28.1 which is incompatible.
# langchain 0.2.15 requires langchain-core<0.3.0,>=0.2.35, but you have langchain-core 0.3.49 which is incompatible.
# langchain 0.2.15 requires langsmith<0.2.0,>=0.1.17, but you have langsmith 0.3.19 which is incompatible.
# gradio 4.29.0 requires markupsafe~=2.0, but you have markupsafe 3.0.2 which is incompatible.
# gradio 4.29.0 requires pillow<11.0,>=8.0, but you have pillow 11.0.0 which is incompatible.
# langfuse 2.44.0 requires idna<4.0,>=3.7, but you have idna 2.10 which is incompatible.
# langfuse 2.44.0 requires packaging<24.0,>=23.2, but you have packaging 24.2 which is incompatible.
# langchain-text-splitters 0.2.4 requires langchain-core<0.3.0,>=0.2.38, but you have langchain-core 0.3.49 which is incompatible.
# langchain-community 0.2.12 requires langchain-core<0.3.0,>=0.2.30, but you have langchain-core 0.3.49 which is incompatible.
# langchain-community 0.2.12 requires langsmith<0.2.0,>=0.1.0, but you have langsmith 0.3.19 which is incompatible.
# unstructured-client 0.25.9 requires idna>=3.4, but you have idna 2.10 which is incompatible.

# %%
import torch
import warnings
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_community.llms import HuggingFacePipeline
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent

# Ignore deprecation warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Ép model về CPU
device = torch.device("cpu")
model_id = "phatvucoder/Qwen2.5-1.5B-Perfumassist"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id).to(device)

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    device=-1  # use CPU
)

llm = HuggingFacePipeline(pipeline=pipe)

# Kết nối DB và tạo agent
db = SQLDatabase.from_uri("sqlite:///perfumes.db")
toolkit = SQLDatabaseToolkit(db=db, llm=llm)
agent = create_sql_agent(llm=llm, toolkit=toolkit, verbose=True)

# Dùng .invoke thay vì .run (theo cảnh báo mới)
response = agent.invoke("Loại nước hoa nào có hương chính là hoa nhài?")
print(response)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cpu
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input:
# Observation: ['fragrance_notes', 'fragrance_collection, inventory
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1359, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1358     # Call the LLM to see what to do.
# -> 1359     output = self._action_agent.plan(
#    1360         intermediate_steps,
#    1361         callbacks=run_manager.get_child() if run_manager else None,
#    1362         **inputs,
#    1363     )
#    1364 except OutputParserException as e:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:462, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     455 if self.stream_runnable:
#     456     # Use streaming to make sure that the underlying LLM is invoked in a
#     457     # streaming
#    (...)
#     460     # Because the response from the plan is not a generator, we need to
#     461     # accumulate the output into final output and return that.
# --> 462     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     463         if final_output is None:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3262, in RunnableSequence.stream(self, input, config, **kwargs)
#    3256 def stream(
#    3257     self,
#    3258     input: Input,
#    3259     config: Optional[RunnableConfig] = None,
#    3260     **kwargs: Optional[Any],
#    3261 ) -> Iterator[Output]:
# -> 3262     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3249, in RunnableSequence.transform(self, input, config, **kwargs)
#    3243 def transform(
#    3244     self,
#    3245     input: Iterator[Input],
#    3246     config: Optional[RunnableConfig] = None,
#    3247     **kwargs: Optional[Any],
#    3248 ) -> Iterator[Output]:
# -> 3249     yield from self._transform_stream_with_config(
#    3250         input,
#    3251         self._transform,
#    3252         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3253         **kwargs,
#    3254     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:2056, in _transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2053             raise first_exception
#    2055 async def _abatch_with_config(
# -> 2056     self,
#    2057     func: Union[
#    2058         Callable[[list[Input]], Awaitable[list[Union[Exception, Output]]]],
#    2059         Callable[
#    2060             [list[Input], list[AsyncCallbackManagerForChainRun]],
#    2061             Awaitable[list[Union[Exception, Output]]],
#    2062         ],
#    2063         Callable[
#    2064             [
#    2065                 list[Input],
#    2066                 list[AsyncCallbackManagerForChainRun],
#    2067                 list[RunnableConfig],
#    2068             ],
#    2069             Awaitable[list[Union[Exception, Output]]],
#    2070         ],
#    2071     ],
#    2072     input: list[Input],
#    2073     config: Optional[Union[RunnableConfig, list[RunnableConfig]]] = None,
#    2074     *,
#    2075     return_exceptions: bool = False,
#    2076     run_type: Optional[str] = None,
#    2077     **kwargs: Optional[Any],
#    2078 ) -> list[Output]:
#    2079     """Helper method to transform an Input value to an Output value,
#    2080     with callbacks. Use this method to implement invoke() in subclasses.
#    2081     """
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:3212, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3210         final_pipeline = step.transform(final_pipeline, config)
# -> 3212 yield from final_pipeline
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:855, in stream(self, input, config, **kwargs)
#     854 finally:
# --> 855     for future in futures:
#     856         future.cancel()
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:192, in invoke(self, input, config)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
# --> 192     if isinstance(input, BaseMessage):
#     193         return self._call_with_config(
#     194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#    (...)
#     199             run_type="parser",
#     200         )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/base.py:1786, in _call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1732 def with_retry(
#    1733     self,
#    1734     *,
#    (...)
#    1737     stop_after_attempt: int = 3,
#    1738 ) -> Runnable[Input, Output]:
#    1739     """Create a new Runnable that retries the original Runnable on exceptions.
#    1740
#    1741     Args:
#    1742         retry_if_exception_type: A tuple of exception types to retry on.
#    1743             Defaults to (Exception,).
#    1744         wait_exponential_jitter: Whether to add jitter to the wait
#    1745             time between retries. Defaults to True.
#    1746         stop_after_attempt: The maximum number of attempts to make before
#    1747             giving up. Defaults to 3.
#    1748
#    1749     Returns:
#    1750         A new Runnable that retries the original Runnable on exceptions.
#    1751
#    1752     Example:
#    1753
#    1754     .. code-block:: python
#    1755
#    1756         from langchain_core.runnables import RunnableLambda
#    1757
#    1758         count = 0
#    1759
#    1760
#    1761         def _lambda(x: int) -> None:
#    1762             global count
#    1763             count = count + 1
#    1764             if x == 1:
#    1765                 raise ValueError("x is 1")
#    1766             else:
#    1767                  pass
#    1768
#    1769
#    1770         runnable = RunnableLambda(_lambda)
#    1771         try:
#    1772             runnable.with_retry(
#    1773                 stop_after_attempt=2,
#    1774                 retry_if_exception_type=(ValueError,),
#    1775             ).invoke(1)
#    1776         except ValueError:
#    1777             pass
#    1778
#    1779         assert (count == 2)
#    1780
#    1781
#    1782     Args:
#    1783         retry_if_exception_type: A tuple of exception types to retry on
#    1784         wait_exponential_jitter: Whether to add jitter to the wait time
#    1785                                  between retries
# -> 1786         stop_after_attempt: The maximum number of attempts to make before giving up
#    1787
#    1788     Returns:
#    1789         A new Runnable that retries the original Runnable on exceptions.
#    1790     """
#    1791     from langchain_core.runnables.retry import RunnableRetry
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/runnables/config.py:398, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     392     return base
#     395 def call_func_with_variable_args(
#     396     func: Union[
#     397         Callable[[Input], Output],
# --> 398         Callable[[Input, RunnableConfig], Output],
#     399         Callable[[Input, CallbackManagerForChainRun], Output],
#     400         Callable[[Input, CallbackManagerForChainRun, RunnableConfig], Output],
#     401     ],
#     402     input: Input,
#     403     config: RunnableConfig,
#     404     run_manager: Optional[CallbackManagerForChainRun] = None,
#     405     **kwargs: Any,
#     406 ) -> Output:
#     407     """Call function that may optionally accept a run_manager and/or config.
#     408
#     409     Args:
#    (...)
#     421         Output: The output of the function.
#     422     """
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:193, in <lambda>(inner_input)
#     192 if isinstance(input, BaseMessage):
# --> 193     return self._call_with_config(
#     194         lambda inner_input: self.parse_result(
#     195             [ChatGeneration(message=inner_input)]
#     196         ),
#     197         input,
#     198         config,
#     199         run_type="parser",
#     200     )
#     201 else:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:237, in parse_result(self, result, partial)
#     232 def parse_result(self, result: list[Generation], *, partial: bool = False) -> T:
#     233     """Parse a list of candidate model Generations into a specific format.
#     234
#     235     The return value is parsed from only the first Generation in the result, which
#     236         is assumed to be the highest-likelihood Generation.
# --> 237
#     238     Args:
#     239         result: A list of Generations to be parsed. The Generations are assumed
#     240             to be different candidate outputs for a single model input.
#     241         partial: Whether to parse the output as a partial result. This is useful
#     242             for parsers that can parse partial results. Default is False.
#     243
#     244     Returns:
#     245         Structured output.
#     246     """
#     247     return self.parse(result[0].text)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/output_parsers/react_single_input.py:75, in ReActSingleInputOutputParser.parse(self, text)
#      74 if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ---> 75     raise OutputParserException(
#      76         f"Could not parse LLM output: `{text}`",
#      77         observation=MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE,
#      78         llm_output=text,
#      79         send_to_llm=True,
#      80     )
#      81 elif not re.search(
#      82     r"[\s]*Action\s*\d*\s*Input\s*\d*\s*:[\s]*(.*)", text, re.DOTALL
#      83 ):
#
# OutputParserException: Could not parse LLM output: ` From the above observations, I need to find out which table(s) may contain the names or details`
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 35
#      32 agent = create_sql_agent(llm=llm, toolkit=toolkit, verbose=True)
#      34 # Dùng .invoke thay vì .run (theo cảnh báo mới)
# ---> 35 response = agent.invoke("Loại nước hoa nào có hương chính là hoa nhài?")
#      36 print(response)
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/chains/base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1331, in <listcomp>(.0)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File ~/miniconda3/lib/python3.11/site-packages/langchain/agents/agent.py:1370, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1368     raise_error = False
#    1369 if raise_error:
# -> 1370     raise ValueError(
#    1371         "An output parsing error occurred. "
#    1372         "In order to pass this error back to the agent and have it try "
#    1373         "again, pass `handle_parsing_errors=True` to the AgentExecutor. "
#    1374         f"This is the error: {str(e)}"
#    1375     )
#    1376 text = str(e)
#    1377 if isinstance(self.handle_parsing_errors, bool):
#
# ValueError: An output parsing error occurred. In order to pass this error back to the agent and have it try again, pass `handle_parsing_errors=True` to the AgentExecutor. This is the error: Could not parse LLM output: ` From the above observations, I need to find out which table(s) may contain the names or details`
